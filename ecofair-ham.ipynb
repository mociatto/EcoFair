# %%
import sys
import os
import logging

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
logging.getLogger('tensorflow').setLevel(logging.FATAL)
try:
    from absl import logging as absl_logging
    absl_logging.set_verbosity(absl_logging.ERROR)
except ImportError:
    pass

import subprocess

REPO_URL = "https://github.com/mociatto/EcoFair.git"
REPO_DIR = "EcoFair"

if os.path.exists("./src"):
    sys.path.insert(0, os.path.abspath("."))
elif os.path.exists(os.path.join(".", REPO_DIR, "src")):
    sys.path.insert(0, os.path.abspath(REPO_DIR))
else:
    subprocess.run(["git", "clone", "--depth", "1", REPO_URL, REPO_DIR], check=True)
    sys.path.insert(0, os.path.abspath(REPO_DIR))

from src import config, utils, data_loader, models, training, features, routing, fairness, visualization
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# Cloning into 'EcoFair'...
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1773395808.540238      24 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1773395808.590533      24 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1773395809.022374      24 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773395809.022421      24 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773395809.022423      24 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773395809.022426      24 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.

# %%
META_PATH = '/kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_metadata.csv'
OUTPUT_BASE = '/kaggle/input/notebooks/mostafaanoosha' if os.path.exists('/kaggle') else './output'

CLASSES = ['akiec', 'bcc', 'bkl', 'df', 'mel', 'nv', 'vasc']
SAFE_CLASSES = ['nv', 'bkl', 'vasc', 'df']
DANGEROUS_CLASSES = ['mel', 'bcc', 'akiec']

TITLE_SUFFIX = ' — HAM10000'
DATASET_NAME = 'HAM10000'
OUTPUT_DIR = os.path.join('./output', 'pipeline_results', DATASET_NAME)

# Build pair directories from config.MODEL_PAIRS
# Path structure: {base}/image-feature-extractor-{lite|heavy}/output/HAM10000/{model}
PAIRS = [
    (os.path.join(OUTPUT_BASE, 'image-feature-extractor-lite', 'output', 'HAM10000', p['lite']),
     os.path.join(OUTPUT_BASE, 'image-feature-extractor-heavy', 'output', 'HAM10000', p['heavy']))
    for p in config.MODEL_PAIRS
]
PAIR_LABELS = [f"{p['lite']} → {p['heavy']}" for p in config.MODEL_PAIRS]

utils.set_seed(config.RANDOM_STATE)

# %%
pairs_data, meta = data_loader.load_dataset_features_multi(
    PAIRS, META_PATH,
    required_columns=['dx', 'age', 'sex', 'localization'],
)

# %%
loc_risk_scores = features.compute_localization_risk_scores(meta, dangerous_classes=DANGEROUS_CLASSES)
X_tab, scaler, sex_encoder, loc_encoder, risk_scaler = features.prepare_tabular_features(
    meta, localization_risk_scores=loc_risk_scores
)
y, _ = features.prepare_labels(meta, class_names=CLASSES)
meta = meta.copy()
meta['risk_score'] = features.calculate_cumulative_risk(
    meta, risk_scaler, localization_risk_scores=loc_risk_scores
)

# %%
print("\nMetadata distributions (age, localization, malignancy rate):\n")
fig_meta = visualization.plot_metadata_distributions(meta, DANGEROUS_CLASSES, title_suffix=TITLE_SUFFIX, verbose=False)
plt.show()
# Out:
# Metadata distributions (age, localization, malignancy rate):

# %%
cv_results = training.run_cv_pipeline_multi(
    pairs_data, PAIRS, X_tab, y, meta,
    class_names=CLASSES, safe_classes=SAFE_CLASSES, dangerous_classes=DANGEROUS_CLASSES,
    n_splits=5, risk_scaler=risk_scaler, routing_strategy='threshold', verbose=False,
)
# Out:
# I0000 00:00:1773395872.358859      24 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15511 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# 0epoch [00:00, ?epoch/s]
# 0batch [00:00, ?batch/s]
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1773395876.409198      78 service.cc:152] XLA service 0x7fea04013ab0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1773395876.409236      78 service.cc:160]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1773395876.947314      78 cuda_dnn.cc:529] Loaded cuDNN version 91002
# I0000 00:00:1773395879.621913      78 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 0epoch [00:00, ?epoch/s]
# 0batch [00:00, ?batch/s]
# 0epoch [00:00, ?epoch/s]
# 0batch [00:00, ?batch/s]
# 0epoch [00:00, ?epoch/s]
# 0batch [00:00, ?batch/s]
# 0epoch [00:00, ?epoch/s]
# 0batch [00:00, ?batch/s]
# 0epoch [00:00, ?epoch/s]
# 0batch [00:00, ?batch/s]
# 0epoch [00:00, ?epoch/s]
# 0batch [00:00, ?batch/s]
# 0epoch [00:00, ?epoch/s]
# 0batch [00:00, ?batch/s]
# 0epoch [00:00, ?epoch/s]
# 0batch [00:00, ?batch/s]
# 0epoch [00:00, ?epoch/s]
# 0batch [00:00, ?batch/s]
# 0epoch [00:00, ?epoch/s]
# 0batch [00:00, ?batch/s]
# 0epoch [00:00, ?epoch/s]
# 0batch [00:00, ?batch/s]
# 0epoch [00:00, ?epoch/s]
# 0batch [00:00, ?batch/s]
# 0epoch [00:00, ?epoch/s]
# 0batch [00:00, ?batch/s]
# 0epoch [00:00, ?epoch/s]
# 0batch [00:00, ?batch/s]
# 0epoch [00:00, ?epoch/s]
# 0batch [00:00, ?batch/s]
# 0epoch [00:00, ?epoch/s]
# 0batch [00:00, ?batch/s]
# 0epoch [00:00, ?epoch/s]
# 0batch [00:00, ?batch/s]
# 0epoch [00:00, ?epoch/s]
# 0batch [00:00, ?batch/s]
# 0epoch [00:00, ?epoch/s]
# 0batch [00:00, ?batch/s]
# 0epoch [00:00, ?epoch/s]
# 0batch [00:00, ?batch/s]
# 0epoch [00:00, ?epoch/s]
# 0batch [00:00, ?batch/s]
# 0epoch [00:00, ?epoch/s]
# 0batch [00:00, ?batch/s]
# 0epoch [00:00, ?epoch/s]
# 0batch [00:00, ?batch/s]
# 0epoch [00:00, ?epoch/s]
# 0batch [00:00, ?batch/s]
# 0epoch [00:00, ?epoch/s]
# 0batch [00:00, ?batch/s]
# 0epoch [00:00, ?epoch/s]
# 0batch [00:00, ?batch/s]
# 0epoch [00:00, ?epoch/s]
# 0batch [00:00, ?batch/s]
# 0epoch [00:00, ?epoch/s]
# 0batch [00:00, ?batch/s]
# 0epoch [00:00, ?epoch/s]
# 0batch [00:00, ?batch/s]

# %%
print("\nTable 1 — Cross-Validation Results (5 folds, 3 pairs):\n")
rows_cv = []
for idx, (fold_metrics, _, _, _, _, _) in enumerate(cv_results):
    plabel = PAIR_LABELS[idx]
    for model in ['lite', 'heavy', 'dynamic']:
        mname = 'Lite' if model == 'lite' else 'Heavy' if model == 'heavy' else 'EcoFair'
        rows_cv.append({
            'Pair': plabel,
            'Model': mname,
            'Macro F1': f"{np.mean(fold_metrics[f'macro_f1_{model}']):.4f} ± {np.std(fold_metrics[f'macro_f1_{model}']):.4f}",
            'Balanced Acc': f"{np.mean(fold_metrics[f'balanced_acc_{model}']):.4f} ± {np.std(fold_metrics[f'balanced_acc_{model}']):.4f}",
            'Malignant Recall': f"{np.mean(fold_metrics[f'malignant_recall_{model}']):.4f} ± {np.std(fold_metrics[f'malignant_recall_{model}']):.4f}",
        })
df_cv = pd.DataFrame(rows_cv)
utils.save_results_csv(df_cv, OUTPUT_DIR, 'cv_results.csv')
df_cv = pd.read_csv(os.path.join(OUTPUT_DIR, 'cv_results.csv'))
utils.show_table(df_cv)
# Out:
# Table 1 — Cross-Validation Results (5 folds, 3 pairs):
#                                 Pair    Model         Macro F1  \
# 0             MobileNetV2 → ResNet50     Lite  0.5305 ± 0.0212
# 1             MobileNetV2 → ResNet50    Heavy  0.5855 ± 0.0177
# 2             MobileNetV2 → ResNet50  EcoFair  0.5629 ± 0.0124
# 3     MobileNetV3Small → DenseNet201     Lite  0.5521 ± 0.0165
# 4     MobileNetV3Small → DenseNet201    Heavy  0.5837 ± 0.0118
# 5     MobileNetV3Small → DenseNet201  EcoFair  0.5774 ± 0.0222
# 6  MobileNetV3Small → EfficientNetB6     Lite  0.5568 ± 0.0205
# 7  MobileNetV3Small → EfficientNetB6    Heavy  0.5468 ± 0.0182
# 8  MobileNetV3Small → EfficientNetB6  EcoFair  0.5784 ± 0.0163
#
#       Balanced Acc Malignant Recall
# 0  0.5932 ± 0.0324  0.5442 ± 0.0467
# 1  0.6431 ± 0.0227  0.5998 ± 0.0308
# 2  0.6224 ± 0.0230  0.5519 ± 0.0299
# 3  0.6244 ± 0.0165  0.6168 ± 0.0342
# 4  0.6338 ± 0.0288  0.5802 ± 0.0206
# 5  0.6440 ± 0.0262  0.5882 ± 0.0477
# 6  0.6285 ± 0.0235  0.5793 ± 0.0335
# 7  0.6141 ± 0.0171  0.5714 ± 0.0142
# 8  0.6506 ± 0.0157  0.5850 ± 0.0251

# %%
print("\nTable 2 — Energy metrics (mean ± std over folds, 3 pairs):\n")
rows_energy = []
for idx, (fold_metrics, _, _, _, _, _) in enumerate(cv_results):
    plabel = PAIR_LABELS[idx]
    lite_dir, heavy_dir = PAIRS[idx]
    j_lite = utils.load_energy_stats(lite_dir) or 1.0
    j_heavy = utils.load_energy_stats(heavy_dir) or 2.5
    eco_mean, eco_std = np.mean(fold_metrics['energy_cost']), np.std(fold_metrics['energy_cost'])
    route_mean, route_std = np.mean(fold_metrics['routing_rate']) * 100, np.std(fold_metrics['routing_rate']) * 100
    savings = [(1 - e / j_heavy) * 100 for e in fold_metrics['energy_cost']]
    sav_mean, sav_std = np.mean(savings), np.std(savings)
    rows_energy.append({
        'Pair': plabel,
        'Lite (J)': f"{j_lite:.2f}",
        'Heavy (J)': f"{j_heavy:.2f}",
        'EcoFair (J)': f"{eco_mean:.2f} ± {eco_std:.2f}",
        'Routing (%)': f"{route_mean:.2f} ± {route_std:.2f}",
        'Savings (%)': f"{sav_mean:.2f} ± {sav_std:.2f}",
    })
df_energy = pd.DataFrame(rows_energy)
utils.save_results_csv(df_energy, OUTPUT_DIR, 'energy_metrics.csv')
df_energy = pd.read_csv(os.path.join(OUTPUT_DIR, 'energy_metrics.csv'))
utils.show_table(df_energy)
# Out:
# Table 2 — Energy metrics (mean ± std over folds, 3 pairs):
#                                 Pair  Lite (J)  Heavy (J)  EcoFair (J)  \
# 0             MobileNetV2 → ResNet50      0.18       0.39  0.28 ± 0.01
# 1     MobileNetV3Small → DenseNet201      0.18       0.84  0.46 ± 0.02
# 2  MobileNetV3Small → EfficientNetB6      0.18       9.62  3.07 ± 0.48
#
#     Routing (%)   Savings (%)
# 0  26.63 ± 2.82  28.09 ± 2.82
# 1  33.32 ± 1.96  45.43 ± 1.96
# 2  30.04 ± 5.02  68.09 ± 5.02

# %%
y_true_oof = np.argmax(y, axis=1)
pairs_results = []
for fold_metrics, oof_lite, oof_heavy, oof_dynamic, _, _ in cv_results:
    pairs_results.append((y_true_oof, oof_lite, oof_heavy, oof_dynamic))

print("\nConfusion-matrix comparison (Lite vs Heavy vs EcoFair, 3 pairs):\n")
fig_cm = visualization.plot_confusion_matrix_comparison_multi(
    pairs_results, CLASSES, pair_labels=PAIR_LABELS
)
plt.show()
# Out:
# Confusion-matrix comparison (Lite vs Heavy vs EcoFair, 3 pairs):

# %%
pairs_fairness_reports = []
for idx, (_, oof_lite, oof_heavy, oof_dynamic, _, _) in enumerate(cv_results):
    lite_pred = np.argmax(oof_lite, axis=1)
    heavy_pred = np.argmax(oof_heavy, axis=1)
    dynamic_pred = np.argmax(oof_dynamic, axis=1)
    fl = fairness.generate_fairness_report(y_true_oof, lite_pred, meta, CLASSES)
    fh = fairness.generate_fairness_report(y_true_oof, heavy_pred, meta, CLASSES)
    fe = fairness.generate_fairness_report(y_true_oof, dynamic_pred, meta, CLASSES)
    pairs_fairness_reports.append({'Lite': fl, 'Heavy': fh, 'EcoFair': fe})

def _fairness_summary(reports, dangerous_classes):
    rows = []
    for label, df in reports.items():
        if df is None or df.empty:
            rows.append({'Model': label, 'macro_tpr_mean': np.nan, 'macro_tpr_worst_group': np.nan, 'macro_tpr_gap': np.nan})
            continue
        subset = df[df['Class'].isin(dangerous_classes)].copy()
        subset['_tpr'] = pd.to_numeric(subset['Equal_Opportunity_TPR'], errors='coerce')
        sg_macro = subset.groupby('Subgroup')['_tpr'].mean().dropna()
        if sg_macro.empty:
            rows.append({'Model': label, 'macro_tpr_mean': np.nan, 'macro_tpr_worst_group': np.nan, 'macro_tpr_gap': np.nan})
            continue
        rows.append({
            'Model': label,
            'macro_tpr_mean': round(float(sg_macro.mean()), 4),
            'macro_tpr_worst_group': round(float(sg_macro.min()), 4),
            'macro_tpr_gap': round(float(sg_macro.max() - sg_macro.min()), 4),
        })
    return pd.DataFrame(rows).set_index('Model')

pd.set_option('display.float_format', '{:.4f}'.format)
rows_fairness = []
for idx, reports in enumerate(pairs_fairness_reports):
    sf = _fairness_summary(reports, DANGEROUS_CLASSES).reset_index()
    sf.insert(0, 'Pair', PAIR_LABELS[idx])
    rows_fairness.append(sf)
df_fairness = pd.concat(rows_fairness, ignore_index=True)
utils.save_results_csv(df_fairness, OUTPUT_DIR, 'fairness_summary.csv')
df_fairness = pd.read_csv(os.path.join(OUTPUT_DIR, 'fairness_summary.csv'))
print("\nFairness summary (dangerous classes, subgroup macro TPR):\n")
utils.show_table(df_fairness)

print("\nFairness grouped-bar plots (macro TPR, worst-group TPR, TPR gap):\n")
fig_fairness = visualization.plot_fairness_summary_grouped(
    pairs_fairness_reports, DANGEROUS_CLASSES, pair_labels=PAIR_LABELS
)
plt.show()
# Out:
# Fairness summary (dangerous classes, subgroup macro TPR):
#                                 Pair    Model  macro_tpr_mean  \
# 0             MobileNetV2 → ResNet50     Lite          0.5704
# 1             MobileNetV2 → ResNet50    Heavy          0.6154
# 2             MobileNetV2 → ResNet50  EcoFair          0.5742
# 3     MobileNetV3Small → DenseNet201     Lite          0.6178
# 4     MobileNetV3Small → DenseNet201    Heavy          0.6086
# 5     MobileNetV3Small → DenseNet201  EcoFair          0.5890
# 6  MobileNetV3Small → EfficientNetB6     Lite          0.6030
# 7  MobileNetV3Small → EfficientNetB6    Heavy          0.5758
# 8  MobileNetV3Small → EfficientNetB6  EcoFair          0.6042
#
#    macro_tpr_worst_group  macro_tpr_gap
# 0                 0.5354         0.1305
# 1                 0.5619         0.1216
# 2                 0.5391         0.1152
# 3                 0.6002         0.0357
# 4                 0.5437         0.1932
# 5                 0.5541         0.0643
# 6                 0.5540         0.1529
# 7                 0.5294         0.0766
# 8                 0.5375         0.1636
# Fairness grouped-bar plots (macro TPR, worst-group TPR, TPR gap):

# %%
def _subgroup_to_df(fairness_df, metric_col):
    if fairness_df is None or fairness_df.empty:
        return pd.DataFrame()
    df = fairness_df.copy()
    df['Subgroup'] = df.apply(lambda r: f"{r['Subgroup']} (n={int(r['Count'])})", axis=1)
    piv = df.pivot(index='Subgroup', columns='Class', values=metric_col).reset_index()
    return piv

subgroup_acc_list, subgroup_eo_list, subgroup_dp_list = [], [], []
for idx, reports in enumerate(pairs_fairness_reports):
    plabel = PAIR_LABELS[idx]
    for model_name, rep in [('Lite', reports['Lite']), ('Heavy', reports['Heavy']), ('EcoFair', reports['EcoFair'])]:
        for piv, lst in [
            (_subgroup_to_df(rep, 'Accuracy'), subgroup_acc_list),
            (_subgroup_to_df(rep, 'Equal_Opportunity_TPR'), subgroup_eo_list),
            (_subgroup_to_df(rep, 'Demographic_Parity_Rate'), subgroup_dp_list),
        ]:
            if piv.empty:
                continue
            piv = piv.copy()
            piv.insert(0, 'Pair', plabel)
            piv.insert(1, 'Model', model_name)
            lst.append(piv)

for fname, lst, title in [
    ('subgroup_accuracy.csv', subgroup_acc_list, 'Subgroup Accuracy (per Pair, per Model)'),
    ('subgroup_eo.csv', subgroup_eo_list, 'Subgroup Equal Opportunity TPR (per Pair, per Model)'),
    ('subgroup_dp.csv', subgroup_dp_list, 'Subgroup Demographic Parity Rate (per Pair, per Model)'),
]:
    if lst:
        df_sg = pd.concat(lst, ignore_index=True)
        utils.save_results_csv(df_sg, OUTPUT_DIR, fname)
        df_sg = pd.read_csv(os.path.join(OUTPUT_DIR, fname))
        print(f"\n{title}:\n")
        utils.show_table(df_sg)
# Out:
# Subgroup Accuracy (per Pair, per Model):
#                                  Pair    Model              Subgroup  akiec  \
# 0              MobileNetV2 → ResNet50     Lite    Age 30-60 (n=6036) 0.9707
# 1              MobileNetV2 → ResNet50     Lite      Age 60+ (n=2799) 0.8710
# 2              MobileNetV2 → ResNet50     Lite      Age <30 (n=1123) 0.9991
# 3              MobileNetV2 → ResNet50     Lite  Sex: Female (n=4548) 0.9648
# 4              MobileNetV2 → ResNet50     Lite    Sex: Male (n=5400) 0.9298
# 5              MobileNetV2 → ResNet50    Heavy    Age 30-60 (n=6036) 0.9770
# 6              MobileNetV2 → ResNet50    Heavy      Age 60+ (n=2799) 0.9018
# 7              MobileNetV2 → ResNet50    Heavy      Age <30 (n=1123) 0.9982
# 8              MobileNetV2 → ResNet50    Heavy  Sex: Female (n=4548) 0.9734
# 9              MobileNetV2 → ResNet50    Heavy    Sex: Male (n=5400) 0.9454
# 10             MobileNetV2 → ResNet50  EcoFair    Age 30-60 (n=6036) 0.9801
# 11             MobileNetV2 → ResNet50  EcoFair      Age 60+ (n=2799) 0.9039
# 12             MobileNetV2 → ResNet50  EcoFair      Age <30 (n=1123) 1.0000
# 13             MobileNetV2 → ResNet50  EcoFair  Sex: Female (n=4548) 0.9767
# 14             MobileNetV2 → ResNet50  EcoFair    Sex: Male (n=5400) 0.9476
# 15     MobileNetV3Small → DenseNet201     Lite    Age 30-60 (n=6036) 0.9723
# 16     MobileNetV3Small → DenseNet201     Lite      Age 60+ (n=2799) 0.8825
# 17     MobileNetV3Small → DenseNet201     Lite      Age <30 (n=1123) 0.9973
# 18     MobileNetV3Small → DenseNet201     Lite  Sex: Female (n=4548) 0.9664
# 19     MobileNetV3Small → DenseNet201     Lite    Sex: Male (n=5400) 0.9359
# 20     MobileNetV3Small → DenseNet201    Heavy    Age 30-60 (n=6036) 0.9776
# 21     MobileNetV3Small → DenseNet201    Heavy      Age 60+ (n=2799) 0.9071
# 22     MobileNetV3Small → DenseNet201    Heavy      Age <30 (n=1123) 1.0000
# 23     MobileNetV3Small → DenseNet201    Heavy  Sex: Female (n=4548) 0.9730
# 24     MobileNetV3Small → DenseNet201    Heavy    Sex: Male (n=5400) 0.9496
# 25     MobileNetV3Small → DenseNet201  EcoFair    Age 30-60 (n=6036) 0.9775
# 26     MobileNetV3Small → DenseNet201  EcoFair      Age 60+ (n=2799) 0.9003
# 27     MobileNetV3Small → DenseNet201  EcoFair      Age <30 (n=1123) 0.9991
# 28     MobileNetV3Small → DenseNet201  EcoFair  Sex: Female (n=4548) 0.9716
# 29     MobileNetV3Small → DenseNet201  EcoFair    Sex: Male (n=5400) 0.9469
# 30  MobileNetV3Small → EfficientNetB6     Lite    Age 30-60 (n=6036) 0.9698
# 31  MobileNetV3Small → EfficientNetB6     Lite      Age 60+ (n=2799) 0.8889
# 32  MobileNetV3Small → EfficientNetB6     Lite      Age <30 (n=1123) 0.9947
# 33  MobileNetV3Small → EfficientNetB6     Lite  Sex: Female (n=4548) 0.9659
# 34  MobileNetV3Small → EfficientNetB6     Lite    Sex: Male (n=5400) 0.9363
# 35  MobileNetV3Small → EfficientNetB6    Heavy    Age 30-60 (n=6036) 0.9743
# 36  MobileNetV3Small → EfficientNetB6    Heavy      Age 60+ (n=2799) 0.8971
# 37  MobileNetV3Small → EfficientNetB6    Heavy      Age <30 (n=1123) 0.9991
# 38  MobileNetV3Small → EfficientNetB6    Heavy  Sex: Female (n=4548) 0.9721
# 39  MobileNetV3Small → EfficientNetB6    Heavy    Sex: Male (n=5400) 0.9413
# 40  MobileNetV3Small → EfficientNetB6  EcoFair    Age 30-60 (n=6036) 0.9747
# 41  MobileNetV3Small → EfficientNetB6  EcoFair      Age 60+ (n=2799) 0.8989
# 42  MobileNetV3Small → EfficientNetB6  EcoFair      Age <30 (n=1123) 0.9982
# 43  MobileNetV3Small → EfficientNetB6  EcoFair  Sex: Female (n=4548) 0.9705
# 44  MobileNetV3Small → EfficientNetB6  EcoFair    Sex: Male (n=5400) 0.9437
#
#       bcc    bkl     df    mel     nv   vasc
# 0  0.9708 0.9125 0.9684 0.8885 0.8393 0.9909
# 1  0.8957 0.7760 0.9800 0.7881 0.8124 0.9879
# 2  0.9911 0.9795 0.9893 0.9270 0.8833 0.9795
# 3  0.9659 0.9026 0.9734 0.8887 0.8423 0.9868
# 4  0.9402 0.8639 0.9744 0.8443 0.8319 0.9904
# 5  0.9680 0.9264 0.9831 0.8857 0.8552 0.9920
# 6  0.8957 0.8064 0.9829 0.7914 0.8228 0.9896
# 7  0.9929 0.9733 0.9938 0.9252 0.8807 0.9831
# 8  0.9650 0.9180 0.9864 0.8846 0.8577 0.9914
# 9  0.9381 0.8809 0.9824 0.8459 0.8415 0.9894
# 10 0.9738 0.9147 0.9689 0.9071 0.8549 0.9904
# 11 0.9046 0.7831 0.9786 0.8017 0.8203 0.9882
# 12 0.9964 0.9795 0.9893 0.9421 0.9047 0.9795
# 13 0.9727 0.9083 0.9736 0.9015 0.8562 0.9870
# 14 0.9435 0.8652 0.9741 0.8644 0.8461 0.9898
# 15 0.9672 0.9129 0.9811 0.8545 0.8199 0.9920
# 16 0.8839 0.7885 0.9850 0.7613 0.8071 0.9879
# 17 0.9911 0.9671 0.9902 0.8620 0.8192 0.9849
# 18 0.9624 0.9013 0.9833 0.8463 0.8208 0.9901
# 19 0.9330 0.8693 0.9831 0.8150 0.8126 0.9900
# 20 0.9672 0.9301 0.9823 0.8824 0.8560 0.9932
# 21 0.8928 0.7978 0.9829 0.7860 0.8249 0.9904
# 22 0.9911 0.9849 0.9955 0.9261 0.8967 0.9849
# 23 0.9628 0.9142 0.9853 0.8843 0.8641 0.9910
# 24 0.9372 0.8861 0.9828 0.8398 0.8415 0.9919
# 25 0.9720 0.9112 0.9808 0.8842 0.8469 0.9920
# 26 0.9007 0.7971 0.9829 0.7856 0.8185 0.9868
# 27 0.9947 0.9671 0.9911 0.9181 0.8762 0.9849
# 28 0.9664 0.9015 0.9831 0.8788 0.8500 0.9894
# 29 0.9444 0.8717 0.9820 0.8446 0.8356 0.9900
# 30 0.9677 0.9139 0.9831 0.8723 0.8368 0.9919
# 31 0.8996 0.7960 0.9800 0.7710 0.8207 0.9879
# 32 0.9929 0.9679 0.9858 0.8736 0.8255 0.9858
# 33 0.9639 0.9055 0.9855 0.8608 0.8347 0.9894
# 34 0.9407 0.8709 0.9800 0.8300 0.8281 0.9906
# 35 0.9662 0.9319 0.9748 0.8789 0.8524 0.9897
# 36 0.8953 0.8071 0.9778 0.7688 0.8264 0.9857
# 37 0.9902 0.9813 0.9893 0.9234 0.8816 0.9786
# 38 0.9624 0.9129 0.9771 0.8760 0.8562 0.9846
# 39 0.9376 0.8933 0.9774 0.8339 0.8420 0.9896
# 40 0.9722 0.9155 0.9811 0.8830 0.8496 0.9919
# 41 0.9103 0.8003 0.9811 0.7949 0.8299 0.9886
# 42 0.9955 0.9679 0.9858 0.9154 0.8682 0.9822
# 43 0.9692 0.9037 0.9848 0.8777 0.8500 0.9888
# 44 0.9474 0.8765 0.9789 0.8489 0.8431 0.9907
# Subgroup Equal Opportunity TPR (per Pair, per Model):
#                                  Pair    Model              Subgroup  akiec  \
# 0              MobileNetV2 → ResNet50     Lite    Age 30-60 (n=6036) 0.6098
# 1              MobileNetV2 → ResNet50     Lite      Age 60+ (n=2799) 0.5665
# 2              MobileNetV2 → ResNet50     Lite      Age <30 (n=1123) 1.0000
# 3              MobileNetV2 → ResNet50     Lite  Sex: Female (n=4548) 0.5472
# 4              MobileNetV2 → ResNet50     Lite    Sex: Male (n=5400) 0.6018
# 5              MobileNetV2 → ResNet50    Heavy    Age 30-60 (n=6036) 0.5772
# 6              MobileNetV2 → ResNet50    Heavy      Age 60+ (n=2799) 0.5813
# 7              MobileNetV2 → ResNet50    Heavy      Age <30 (n=1123) 1.0000
# 8              MobileNetV2 → ResNet50    Heavy  Sex: Female (n=4548) 0.5660
# 9              MobileNetV2 → ResNet50    Heavy    Sex: Male (n=5400) 0.5882
# 10             MobileNetV2 → ResNet50  EcoFair    Age 30-60 (n=6036) 0.6260
# 11             MobileNetV2 → ResNet50  EcoFair      Age 60+ (n=2799) 0.5714
# 12             MobileNetV2 → ResNet50  EcoFair      Age <30 (n=1123) 1.0000
# 13             MobileNetV2 → ResNet50  EcoFair  Sex: Female (n=4548) 0.5755
# 14             MobileNetV2 → ResNet50  EcoFair    Sex: Male (n=5400) 0.6018
# 15     MobileNetV3Small → DenseNet201     Lite    Age 30-60 (n=6036) 0.6423
# 16     MobileNetV3Small → DenseNet201     Lite      Age 60+ (n=2799) 0.6256
# 17     MobileNetV3Small → DenseNet201     Lite      Age <30 (n=1123) 1.0000
# 18     MobileNetV3Small → DenseNet201     Lite  Sex: Female (n=4548) 0.5943
# 19     MobileNetV3Small → DenseNet201     Lite    Sex: Male (n=5400) 0.6516
# 20     MobileNetV3Small → DenseNet201    Heavy    Age 30-60 (n=6036) 0.5203
# 21     MobileNetV3Small → DenseNet201    Heavy      Age 60+ (n=2799) 0.5172
# 22     MobileNetV3Small → DenseNet201    Heavy      Age <30 (n=1123) 1.0000
# 23     MobileNetV3Small → DenseNet201    Heavy  Sex: Female (n=4548) 0.5000
# 24     MobileNetV3Small → DenseNet201    Heavy    Sex: Male (n=5400) 0.5294
# 25     MobileNetV3Small → DenseNet201  EcoFair    Age 30-60 (n=6036) 0.5610
# 26     MobileNetV3Small → DenseNet201  EcoFair      Age 60+ (n=2799) 0.5468
# 27     MobileNetV3Small → DenseNet201  EcoFair      Age <30 (n=1123) 1.0000
# 28     MobileNetV3Small → DenseNet201  EcoFair  Sex: Female (n=4548) 0.5283
# 29     MobileNetV3Small → DenseNet201  EcoFair    Sex: Male (n=5400) 0.5656
# 30  MobileNetV3Small → EfficientNetB6     Lite    Age 30-60 (n=6036) 0.6585
# 31  MobileNetV3Small → EfficientNetB6     Lite      Age 60+ (n=2799) 0.6256
# 32  MobileNetV3Small → EfficientNetB6     Lite      Age <30 (n=1123) 1.0000
# 33  MobileNetV3Small → EfficientNetB6     Lite  Sex: Female (n=4548) 0.6509
# 34  MobileNetV3Small → EfficientNetB6     Lite    Sex: Male (n=5400) 0.6335
# 35  MobileNetV3Small → EfficientNetB6    Heavy    Age 30-60 (n=6036) 0.5610
# 36  MobileNetV3Small → EfficientNetB6    Heavy      Age 60+ (n=2799) 0.5862
# 37  MobileNetV3Small → EfficientNetB6    Heavy      Age <30 (n=1123) 1.0000
# 38  MobileNetV3Small → EfficientNetB6    Heavy  Sex: Female (n=4548) 0.5660
# 39  MobileNetV3Small → EfficientNetB6    Heavy    Sex: Male (n=5400) 0.5837
# 40  MobileNetV3Small → EfficientNetB6  EcoFair    Age 30-60 (n=6036) 0.6504
# 41  MobileNetV3Small → EfficientNetB6  EcoFair      Age 60+ (n=2799) 0.6404
# 42  MobileNetV3Small → EfficientNetB6  EcoFair      Age <30 (n=1123) 1.0000
# 43  MobileNetV3Small → EfficientNetB6  EcoFair  Sex: Female (n=4548) 0.6415
# 44  MobileNetV3Small → EfficientNetB6  EcoFair    Sex: Male (n=5400) 0.6471
#
#       bcc    bkl     df    mel     nv   vasc
# 0  0.5035 0.4842 0.4400 0.4930 0.8447 0.7857
# 1  0.5863 0.6079 0.4412 0.5172 0.5311 0.6000
# 2  0.8750 0.2500 0.3333 0.1228 0.9289 0.8148
# 3  0.6650 0.6177 0.5385 0.4552 0.8395 0.7808
# 4  0.5079 0.5064 0.3492 0.5051 0.7858 0.6812
# 5  0.5319 0.5633 0.6933 0.5765 0.8545 0.7571
# 6  0.6630 0.6362 0.2353 0.6370 0.5280 0.7333
# 7  0.8750 0.4167 0.3333 0.1754 0.9239 0.7778
# 8  0.7157 0.6911 0.6923 0.5731 0.8426 0.8356
# 9  0.5773 0.5399 0.4127 0.5939 0.7940 0.6667
# 10 0.5319 0.5679 0.5200 0.4592 0.8693 0.7857
# 11 0.6219 0.6976 0.4412 0.5100 0.5590 0.6667
# 12 0.8750 0.2500 0.3333 0.0877 0.9545 0.8148
# 13 0.7005 0.7235 0.5577 0.4175 0.8617 0.7945
# 14 0.5394 0.5783 0.4286 0.4949 0.8139 0.7101
# 15 0.5461 0.4593 0.5733 0.6123 0.8033 0.8000
# 16 0.6521 0.5055 0.3235 0.6062 0.4855 0.7556
# 17 0.7500 0.4167 0.1667 0.1579 0.8498 0.8519
# 18 0.6802 0.5832 0.6346 0.5519 0.7884 0.8356
# 19 0.5899 0.4137 0.3492 0.6070 0.7416 0.7536
# 20 0.5461 0.4887 0.6133 0.5646 0.8659 0.7714
# 21 0.6767 0.5874 0.4118 0.6189 0.5559 0.8222
# 22 1.0000 0.4167 0.5000 0.2105 0.9387 0.7407
# 23 0.7056 0.6112 0.6731 0.5307 0.8614 0.8356
# 24 0.6088 0.4968 0.4444 0.5997 0.8039 0.7246
# 25 0.5248 0.5271 0.6400 0.5765 0.8439 0.8143
# 26 0.6904 0.6157 0.3529 0.5862 0.5321 0.8222
# 27 0.7500 0.5000 0.3333 0.1053 0.9170 0.8519
# 28 0.6853 0.6523 0.6731 0.5024 0.8354 0.8493
# 29 0.6215 0.5240 0.4286 0.5910 0.7852 0.7971
# 30 0.4468 0.4593 0.6267 0.5567 0.8336 0.8143
# 31 0.5781 0.5591 0.3529 0.5771 0.5600 0.8222
# 32 0.8750 0.4167 0.1667 0.2456 0.8518 0.8519
# 33 0.5838 0.5853 0.6154 0.5212 0.8212 0.8356
# 34 0.5237 0.4665 0.4444 0.5691 0.7738 0.8116
# 35 0.4965 0.5339 0.5200 0.5308 0.8541 0.7571
# 36 0.6493 0.6094 0.2647 0.5681 0.5393 0.7778
# 37 0.6250 0.2500 0.3333 0.1930 0.9229 0.8519
# 38 0.6650 0.6285 0.5192 0.4717 0.8466 0.8082
# 39 0.5710 0.5351 0.3651 0.5691 0.7931 0.7536
# 40 0.4610 0.5136 0.6667 0.5010 0.8539 0.8571
# 41 0.6301 0.6236 0.3529 0.5699 0.5839 0.8667
# 42 0.8750 0.4167 0.1667 0.2281 0.9012 0.8519
# 43 0.6396 0.6177 0.6346 0.4717 0.8463 0.8767
# 44 0.5552 0.5463 0.4762 0.5517 0.7992 0.8406
# Subgroup Demographic Parity Rate (per Pair, per Model):
#                                  Pair    Model              Subgroup  akiec  \
# 0              MobileNetV2 → ResNet50     Lite    Age 30-60 (n=6036) 0.0338
# 1              MobileNetV2 → ResNet50     Lite      Age 60+ (n=2799) 0.1386
# 2              MobileNetV2 → ResNet50     Lite      Age <30 (n=1123) 0.0018
# 3              MobileNetV2 → ResNet50     Lite  Sex: Female (n=4548) 0.0374
# 4              MobileNetV2 → ResNet50     Lite    Sex: Male (n=5400) 0.0785
# 5              MobileNetV2 → ResNet50    Heavy    Age 30-60 (n=6036) 0.0262
# 6              MobileNetV2 → ResNet50    Heavy      Age 60+ (n=2799) 0.1100
# 7              MobileNetV2 → ResNet50    Heavy      Age <30 (n=1123) 0.0027
# 8              MobileNetV2 → ResNet50    Heavy  Sex: Female (n=4548) 0.0297
# 9              MobileNetV2 → ResNet50    Heavy    Sex: Male (n=5400) 0.0619
# 10             MobileNetV2 → ResNet50  EcoFair    Age 30-60 (n=6036) 0.0250
# 11             MobileNetV2 → ResNet50  EcoFair      Age 60+ (n=2799) 0.1065
# 12             MobileNetV2 → ResNet50  EcoFair      Age <30 (n=1123) 0.0009
# 13             MobileNetV2 → ResNet50  EcoFair  Sex: Female (n=4548) 0.0268
# 14             MobileNetV2 → ResNet50  EcoFair    Sex: Male (n=5400) 0.0607
# 15     MobileNetV3Small → DenseNet201     Lite    Age 30-60 (n=6036) 0.0335
# 16     MobileNetV3Small → DenseNet201     Lite      Age 60+ (n=2799) 0.1358
# 17     MobileNetV3Small → DenseNet201     Lite      Age <30 (n=1123) 0.0036
# 18     MobileNetV3Small → DenseNet201     Lite  Sex: Female (n=4548) 0.0380
# 19     MobileNetV3Small → DenseNet201     Lite    Sex: Male (n=5400) 0.0765
# 20     MobileNetV3Small → DenseNet201    Heavy    Age 30-60 (n=6036) 0.0232
# 21     MobileNetV3Small → DenseNet201    Heavy      Age 60+ (n=2799) 0.0954
# 22     MobileNetV3Small → DenseNet201    Heavy      Age <30 (n=1123) 0.0009
# 23     MobileNetV3Small → DenseNet201    Heavy  Sex: Female (n=4548) 0.0270
# 24     MobileNetV3Small → DenseNet201    Heavy    Sex: Male (n=5400) 0.0528
# 25     MobileNetV3Small → DenseNet201  EcoFair    Age 30-60 (n=6036) 0.0250
# 26     MobileNetV3Small → DenseNet201  EcoFair      Age 60+ (n=2799) 0.1065
# 27     MobileNetV3Small → DenseNet201  EcoFair      Age <30 (n=1123) 0.0018
# 28     MobileNetV3Small → DenseNet201  EcoFair  Sex: Female (n=4548) 0.0297
# 29     MobileNetV3Small → DenseNet201  EcoFair    Sex: Male (n=5400) 0.0585
# 30  MobileNetV3Small → EfficientNetB6     Lite    Age 30-60 (n=6036) 0.0366
# 31  MobileNetV3Small → EfficientNetB6     Lite      Age 60+ (n=2799) 0.1293
# 32  MobileNetV3Small → EfficientNetB6     Lite      Age <30 (n=1123) 0.0062
# 33  MobileNetV3Small → EfficientNetB6     Lite  Sex: Female (n=4548) 0.0411
# 34  MobileNetV3Small → EfficientNetB6     Lite    Sex: Male (n=5400) 0.0746
# 35  MobileNetV3Small → EfficientNetB6    Heavy    Age 30-60 (n=6036) 0.0282
# 36  MobileNetV3Small → EfficientNetB6    Heavy      Age 60+ (n=2799) 0.1154
# 37  MobileNetV3Small → EfficientNetB6    Heavy      Age <30 (n=1123) 0.0018
# 38  MobileNetV3Small → EfficientNetB6    Heavy  Sex: Female (n=4548) 0.0310
# 39  MobileNetV3Small → EfficientNetB6    Heavy    Sex: Male (n=5400) 0.0656
# 40  MobileNetV3Small → EfficientNetB6  EcoFair    Age 30-60 (n=6036) 0.0315
# 41  MobileNetV3Small → EfficientNetB6  EcoFair      Age 60+ (n=2799) 0.1215
# 42  MobileNetV3Small → EfficientNetB6  EcoFair      Age <30 (n=1123) 0.0027
# 43  MobileNetV3Small → EfficientNetB6  EcoFair  Sex: Female (n=4548) 0.0361
# 44  MobileNetV3Small → EfficientNetB6  EcoFair    Sex: Male (n=5400) 0.0683
#
#       bcc    bkl     df    mel     nv   vasc
# 0  0.0293 0.0852 0.0302 0.1103 0.6955 0.0157
# 1  0.1268 0.2730 0.0186 0.2186 0.2090 0.0154
# 2  0.0142 0.0151 0.0089 0.0347 0.8896 0.0356
# 3  0.0484 0.1214 0.0275 0.1029 0.6403 0.0222
# 4  0.0607 0.1376 0.0220 0.1570 0.5298 0.0143
# 5  0.0335 0.0828 0.0217 0.1271 0.6948 0.0139
# 6  0.1468 0.2554 0.0107 0.2626 0.1965 0.0179
# 7  0.0125 0.0249 0.0045 0.0419 0.8833 0.0303
# 8  0.0536 0.1209 0.0180 0.1291 0.6293 0.0193
# 9  0.0709 0.1283 0.0156 0.1780 0.5306 0.0148
# 10 0.0277 0.0953 0.0316 0.0861 0.7180 0.0162
# 11 0.1272 0.3065 0.0200 0.2022 0.2204 0.0171
# 12 0.0089 0.0151 0.0089 0.0160 0.9145 0.0356
# 13 0.0446 0.1372 0.0277 0.0831 0.6581 0.0224
# 14 0.0611 0.1530 0.0243 0.1343 0.5511 0.0156
# 15 0.0350 0.0812 0.0207 0.1642 0.6506 0.0149
# 16 0.1558 0.2140 0.0107 0.2805 0.1829 0.0204
# 17 0.0125 0.0312 0.0062 0.1033 0.8112 0.0321
# 18 0.0532 0.1157 0.0198 0.1634 0.5893 0.0207
# 19 0.0776 0.1107 0.0133 0.2122 0.4931 0.0165
# 20 0.0350 0.0683 0.0205 0.1284 0.7116 0.0131
# 21 0.1533 0.2419 0.0150 0.2608 0.2136 0.0200
# 22 0.0160 0.0134 0.0045 0.0445 0.8940 0.0267
# 23 0.0550 0.1084 0.0187 0.1214 0.6497 0.0198
# 24 0.0756 0.1131 0.0159 0.1856 0.5431 0.0139
# 25 0.0292 0.0928 0.0227 0.1286 0.6865 0.0152
# 26 0.1490 0.2554 0.0136 0.2483 0.2036 0.0236
# 27 0.0089 0.0329 0.0071 0.0419 0.8753 0.0321
# 28 0.0497 0.1295 0.0209 0.1216 0.6269 0.0218
# 29 0.0698 0.1339 0.0163 0.1785 0.5254 0.0176
# 30 0.0298 0.0802 0.0200 0.1372 0.6807 0.0154
# 31 0.1208 0.2308 0.0164 0.2594 0.2208 0.0225
# 32 0.0125 0.0303 0.0107 0.1006 0.8085 0.0312
# 33 0.0433 0.1119 0.0172 0.1431 0.6220 0.0213
# 34 0.0620 0.1213 0.0187 0.1876 0.5183 0.0174
# 35 0.0336 0.0731 0.0257 0.1262 0.6970 0.0162
# 36 0.1436 0.2426 0.0164 0.2579 0.2008 0.0232
# 37 0.0116 0.0134 0.0089 0.0454 0.8807 0.0383
# 38 0.0519 0.1132 0.0233 0.1187 0.6365 0.0253
# 39 0.0707 0.1148 0.0194 0.1837 0.5289 0.0169
# 40 0.0260 0.0865 0.0230 0.1171 0.6995 0.0164
# 41 0.1236 0.2558 0.0154 0.2326 0.2279 0.0232
# 42 0.0098 0.0303 0.0107 0.0570 0.8549 0.0347
# 43 0.0429 0.1203 0.0182 0.1170 0.6423 0.0233
# 44 0.0591 0.1343 0.0206 0.1643 0.5356 0.0180

# %%
pairs_fairness_tuples = [(r['Lite'], r['Heavy'], r['EcoFair']) for r in pairs_fairness_reports]
print("\nClinical safety rescue plots (subgroup malignancy TPR, Lite vs EcoFair vs Heavy):\n")
fig_clinical = visualization.plot_clinical_safety_rescue_multi(
    pairs_fairness_tuples, DANGEROUS_CLASSES, pair_labels=PAIR_LABELS
)
plt.show()
# Out:
# Clinical safety rescue plots (subgroup malignancy TPR, Lite vs EcoFair vs Heavy):

# %%
pairs_oof = [(r[1], r[2]) for r in cv_results]  # oof_lite, oof_heavy per pair
pairs_joules = [(utils.load_energy_stats(PAIRS[i][0]) or 1.0, utils.load_energy_stats(PAIRS[i][1]) or 2.5) for i in range(len(PAIRS))]
print("\nPareto frontier: Total energy vs worst-group TPR (3 pairs):\n")
fig_pareto = visualization.plot_pareto_frontier_multi(
    pairs_oof, pairs_joules, y_true_oof, meta, CLASSES, SAFE_CLASSES, DANGEROUS_CLASSES,
    pair_labels=PAIR_LABELS, title_suffix=TITLE_SUFFIX,
    csv_path=os.path.join(OUTPUT_DIR, 'pareto_points.csv')
)
plt.show()
# Out:
# Pareto frontier: Total energy vs worst-group TPR (3 pairs):
